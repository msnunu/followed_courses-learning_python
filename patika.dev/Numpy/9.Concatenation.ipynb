# %%
import numpy as np

# %% [markdown]
# ## Concatenation

# %%
a = np.array( [1, 2, 3, 4] )

# %%
b = np.array( [5, 6, 7, 8] )

# %%
a
# Out:
# array([1, 2, 3, 4])

# %%
b
# Out:
# array([5, 6, 7, 8])

# %%
# a veya b güncellenmez
np.concatenate( [a, b] )
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
# python listlerini de numpy arrayleri ile concatenation'a sokabiliriz

# %%
l = [10, 11]

# %%
np.concatenate( [a, b, l] )
# Out:
# array([ 1,  2,  3,  4,  5,  6,  7,  8, 10, 11])

# %%
l = [10, 11, 11.2]

# %%
np.concatenate( [a, b, l] )
# Out:
# array([ 1. ,  2. ,  3. ,  4. ,  5. ,  6. ,  7. ,  8. , 10. , 11. , 11.2])

# %%
l = [10, 11, "11.2"]

# %%
np.concatenate( [a, b, l] )
# Out:
# array(['1', '2', '3', '4', '5', '6', '7', '8', '10', '11', '11.2'],
#       dtype='<U11')

# %%
# tuple de ekletebilirim
l = (10, 12)

# %%
np.concatenate( [a, b, l] )
# Out:
# array([ 1,  2,  3,  4,  5,  6,  7,  8, 10, 12])

# %% [markdown]
# ## Size Mismatch

# %% [markdown]
# ![axis.JPG](attachment:axis.JPG)

# %%
a
# Out:
# array([1, 2, 3, 4])

# %%
x = np.array( [ [1, 2, 3],
                       [4, 5, 6] ] )

# %%
x
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
x.shape
# Out:
# (2, 3)

# %%
x.size
# Out:
# 6

# %%
a.shape
# Out:
# (4,)

# %%
# shape mismatch
np.concatenate( [x, a] )
# error : all the input arrays must have same number of dimensions
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-ff95de2f2071> in <module>
#       1 # shape mismatch
# ----> 2 np.concatenate( [x, a] )
#       3 # error : all the input arrays must have same number of dimensions
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 2 dimension(s) and the array at index 1 has 1 dimension(s)

# %%
np.concatenate( [x, x] ) # default axis=0
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [1, 2, 3],
#        [4, 5, 6]])

# %%
np.concatenate( [x, x], axis = 1)
# Out:
# array([[1, 2, 3, 1, 2, 3],
#        [4, 5, 6, 4, 5, 6]])

# %%
np.concatenate( [a, a], axis = 0) == np.concatenate( [a, a] )
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True])

# %%
np.concatenate( [a, a], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-28-85e4da2e63fc> in <module>
# ----> 1 np.concatenate( [a, a], axis = 1)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
a
# Out:
# array([1, 2, 3, 4])

# %%
np.concatenate( [a, a] )
# Out:
# array([1, 2, 3, 4, 1, 2, 3, 4])

# %%
P, N, M = map(int,input().split())
# Out:
# 2 3 4

# %%
P
# Out:
# 2

# %%
N
# Out:
# 3

# %%
M
# Out:
# 4

# %%
A = np.array([input().split() for _ in range(M)],int)
# Out:
# 2 3 4
# 2 3 4
# 2 3 4
# 2 3 4

# %%
B = np.array([input().split() for _ in range(N)],int)
# Out:
# 4 5 6
# 4 5 6
# 4 5 6

# %%
print(np.concatenate((A, B), axis = 0))
# Out:
# [[2 3 4]
#  [2 3 4]
#  [2 3 4]
#  [2 3 4]
#  [4 5 6]
#  [4 5 6]
#  [4 5 6]]
